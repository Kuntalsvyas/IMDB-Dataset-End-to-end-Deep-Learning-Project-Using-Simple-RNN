# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
#Sentences
sent=['the glass of milk',
      'the glass of juice',
      'the cup of tea',
      'I am a good boy',
      'I am a good developer',
      'understand the meaning of words',
      'your videos are good',]
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
#Define the vocabulary size
voc_size=10000
#One Hot Representation 
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[7315, 2572, 9684, 8724],
#  [7315, 2572, 9684, 2111],
#  [7315, 3504, 9684, 740],
#  [6568, 4444, 3073, 1219, 9174],
#  [6568, 4444, 3073, 1219, 2977],
#  [8053, 7315, 784, 9684, 9622],
#  [7029, 3834, 114, 1219]]

# %%
#Word Embedding Representation 
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_length=8
embedding_doc=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
embedding_doc
# Out:
# array([[   0,    0,    0,    0, 7315, 2572, 9684, 8724],
#        [   0,    0,    0,    0, 7315, 2572, 9684, 2111],
#        [   0,    0,    0,    0, 7315, 3504, 9684,  740],
#        [   0,    0,    0, 6568, 4444, 3073, 1219, 9174],
#        [   0,    0,    0, 6568, 4444, 3073, 1219, 2977],
#        [   0,    0,    0, 8053, 7315,  784, 9684, 9622],
#        [   0,    0,    0,    0, 7029, 3834,  114, 1219]])

# %%
#feature representation 
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedding_doc)
# Out:
# 1/1 [==============================] - 0s 90ms/step
# array([[[-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.00225226, -0.03999654,  0.02044647, -0.02556984,
#           0.02538848, -0.01037786, -0.0452705 ,  0.01921869,
#          -0.0321046 ,  0.04179344],
#         [-0.0439943 , -0.02261828, -0.03493183, -0.03545562,
#           0.01071838, -0.03203908, -0.02221897, -0.01673424,
#           0.00598085,  0.01372996],
#         [-0.01619493, -0.03874205, -0.01382954,  0.01141331,
#          -0.04540545,  0.0176344 , -0.04003919, -0.03776813,
#          -0.00892567, -0.00409544],
#         [ 0.0143719 , -0.01359148, -0.00464293,  0.02335444,
#           0.01594521,  0.02874747,  0.01491559, -0.01319142,
#           0.01552786, -0.02799712]],
#
#        [[-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.00225226, -0.03999654,  0.02044647, -0.02556984,
#           0.02538848, -0.01037786, -0.0452705 ,  0.01921869,
#          -0.0321046 ,  0.04179344],
#         [-0.0439943 , -0.02261828, -0.03493183, -0.03545562,
#           0.01071838, -0.03203908, -0.02221897, -0.01673424,
#           0.00598085,  0.01372996],
#         [-0.01619493, -0.03874205, -0.01382954,  0.01141331,
#          -0.04540545,  0.0176344 , -0.04003919, -0.03776813,
#          -0.00892567, -0.00409544],
#         [ 0.04083501,  0.01991208, -0.01280742, -0.0474581 ,
#           0.02548381, -0.02715614,  0.00189605, -0.03418254,
#           0.02719214,  0.04950447]],
#
#        [[-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.00225226, -0.03999654,  0.02044647, -0.02556984,
#           0.02538848, -0.01037786, -0.0452705 ,  0.01921869,
#          -0.0321046 ,  0.04179344],
#         [ 0.0283085 ,  0.0367246 ,  0.04452265, -0.03273068,
#          -0.02436062,  0.03599406, -0.00302875,  0.00997764,
#          -0.02291814, -0.0110953 ],
#         [-0.01619493, -0.03874205, -0.01382954,  0.01141331,
#          -0.04540545,  0.0176344 , -0.04003919, -0.03776813,
#          -0.00892567, -0.00409544],
#         [-0.03857253,  0.04716749, -0.01024713, -0.00482879,
#           0.04287263, -0.02931721,  0.00060123, -0.01966058,
#          -0.00089536, -0.00922304]],
#
#        [[-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [ 0.04307543, -0.01349176, -0.00905442,  0.00834756,
#           0.03523466, -0.04022347,  0.03646716,  0.02189544,
#           0.04574475, -0.04813872],
#         [-0.02348351,  0.00158002,  0.03477544, -0.04338566,
#          -0.00408996,  0.01398671,  0.02267205,  0.04271207,
#          -0.03452007, -0.01113588],
#         [-0.00849483, -0.04785797,  0.00100756,  0.02461116,
#           0.02392352,  0.0251343 , -0.0291505 , -0.00310213,
#          -0.02717412,  0.01056981],
#         [-0.04534118, -0.02732936, -0.02689234, -0.01301954,
#           0.00513756, -0.04457635,  0.03709077, -0.02655904,
#           0.00403217, -0.02104334],
#         [ 0.01902938,  0.02418334, -0.0453221 , -0.00969324,
#           0.00318824, -0.04171399,  0.03429439, -0.0220433 ,
#           0.03793966,  0.04063683]],
#
#        [[-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [ 0.04307543, -0.01349176, -0.00905442,  0.00834756,
#           0.03523466, -0.04022347,  0.03646716,  0.02189544,
#           0.04574475, -0.04813872],
#         [-0.02348351,  0.00158002,  0.03477544, -0.04338566,
#          -0.00408996,  0.01398671,  0.02267205,  0.04271207,
#          -0.03452007, -0.01113588],
#         [-0.00849483, -0.04785797,  0.00100756,  0.02461116,
#           0.02392352,  0.0251343 , -0.0291505 , -0.00310213,
#          -0.02717412,  0.01056981],
#         [-0.04534118, -0.02732936, -0.02689234, -0.01301954,
#           0.00513756, -0.04457635,  0.03709077, -0.02655904,
#           0.00403217, -0.02104334],
#         [-0.01878917,  0.03874071,  0.01083948, -0.03203272,
#           0.04331309, -0.03489487,  0.00994644, -0.01830335,
#          -0.04251036, -0.0417943 ]],
#
#        [[-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04420979,  0.03345439, -0.02722283, -0.03955798,
#           0.04355668,  0.0272813 ,  0.02831108, -0.02610159,
#           0.0280706 , -0.01952746],
#         [-0.00225226, -0.03999654,  0.02044647, -0.02556984,
#           0.02538848, -0.01037786, -0.0452705 ,  0.01921869,
#          -0.0321046 ,  0.04179344],
#         [-0.00791328,  0.02804562, -0.02363157, -0.02154846,
#          -0.03190298,  0.01729235,  0.02810151,  0.04092452,
#          -0.01384369,  0.01126065],
#         [-0.01619493, -0.03874205, -0.01382954,  0.01141331,
#          -0.04540545,  0.0176344 , -0.04003919, -0.03776813,
#          -0.00892567, -0.00409544],
#         [-0.01490508, -0.04223125, -0.04639702, -0.03368528,
#          -0.02908425, -0.04612852,  0.00142049,  0.04137892,
#           0.04827782,  0.02617011]],
#
#        [[-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [-0.04995392,  0.02776304, -0.02309115,  0.00085126,
#          -0.0275683 , -0.04763616, -0.01012208,  0.01204833,
#          -0.01663598, -0.01675863],
#         [ 0.01424897, -0.0360337 , -0.00352369,  0.03800801,
#          -0.02993716,  0.0315645 , -0.01985357,  0.03339107,
#          -0.00690132, -0.00819431],
#         [-0.01529287,  0.03418123,  0.02634771,  0.00273233,
#           0.01773273,  0.039613  ,  0.01731466, -0.0365883 ,
#           0.02184268,  0.0425786 ],
#         [ 0.01202847,  0.02661118, -0.01197652,  0.00650702,
#          -0.00515651,  0.04727997,  0.03870609, -0.0298815 ,
#           0.02314368,  0.00389121],
#         [-0.04534118, -0.02732936, -0.02689234, -0.01301954,
#           0.00513756, -0.04457635,  0.03709077, -0.02655904,
#           0.00403217, -0.02104334]]], dtype=float32)

# %%
embedding_doc[0]
# Out:
# array([   0,    0,    0,    0, 7315, 2572, 9684, 8724])

# %%
model.predict(embedding_doc[0])
# Out:
# 1/1 [==============================] - 0s 122ms/step
# array([[-0.04995392,  0.02776304, -0.02309115,  0.00085126, -0.0275683 ,
#         -0.04763616, -0.01012208,  0.01204833, -0.01663598, -0.01675863],
#        [-0.04995392,  0.02776304, -0.02309115,  0.00085126, -0.0275683 ,
#         -0.04763616, -0.01012208,  0.01204833, -0.01663598, -0.01675863],
#        [-0.04995392,  0.02776304, -0.02309115,  0.00085126, -0.0275683 ,
#         -0.04763616, -0.01012208,  0.01204833, -0.01663598, -0.01675863],
#        [-0.04995392,  0.02776304, -0.02309115,  0.00085126, -0.0275683 ,
#         -0.04763616, -0.01012208,  0.01204833, -0.01663598, -0.01675863],
#        [-0.00225226, -0.03999654,  0.02044647, -0.02556984,  0.02538848,
#         -0.01037786, -0.0452705 ,  0.01921869, -0.0321046 ,  0.04179344],
#        [-0.0439943 , -0.02261828, -0.03493183, -0.03545562,  0.01071838,
#         -0.03203908, -0.02221897, -0.01673424,  0.00598085,  0.01372996],
#        [-0.01619493, -0.03874205, -0.01382954,  0.01141331, -0.04540545,
#          0.0176344 , -0.04003919, -0.03776813, -0.00892567, -0.00409544],
#        [ 0.0143719 , -0.01359148, -0.00464293,  0.02335444,  0.01594521,
#          0.02874747,  0.01491559, -0.01319142,  0.01552786, -0.02799712]],
#       dtype=float32)
